# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Домашнее задание "Классификация и кластеризация"

# %% [markdown]
# ### Задание 1
#
# Попробуем определить возраст опоссумов по их размерам. Для работы используйте набор данных по ссылке.
#
# Описание датасета:
# - case: observation number
# - site: The site number where the possum was trapped.
# - Pop: Population, either Vic (Victoria) or other (New South Wales or Queensland).
# - sex: Gender, either m (male) or f (female).
# - age: Age.
# - hdlngth: Head length, in mm.
# - skullw: Skull width, in mm.
# - totlngth: Total length, in cm.
# - taill: Tail length, in cm.
# - footlgth: foot length
